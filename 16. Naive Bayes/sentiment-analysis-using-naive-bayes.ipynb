# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('IMDB Dataset.csv')

# %%
df.head() # This is the data we got
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# One review
df['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %% [markdown]
# ## Text Cleaning
#
# 1. Sample 10000 rows
# 2. Remove html tags
# 3. Remove special characters
# 4. Converting every thing to lower case
# 5. Removing Stop words
# 6. Stemming

# %%
df=df.sample(10000)

# %%
df.shape
# Out:
# (10000, 2)

# %%
df.head()
# Out:
#                                                   review sentiment
# 1750   I must say that I am fairly disappointed by th...  negative
# 38342  Ever heard of a taiwanese horror movie? Or any...  negative
# 19745  How do I describe the horrors?!!! First, some ...  negative
# 29191  The thing which makes "Fire" even more appeali...  positive
# 48684  "Erendira" is a film from Mexico that is rarel...  positive

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10000 entries, 1750 to 41463
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     10000 non-null  str
#  1   sentiment  10000 non-null  str
# dtypes: str(2)
# memory usage: 12.7 MB

# %%
df = df.replace({'sentiment':{'positive':1 ,'negative':0}}) # We Binary encoded the sentiment Column

# %%
df.head()
# Out:
#                                                   review sentiment
# 1750   I must say that I am fairly disappointed by th...         0
# 38342  Ever heard of a taiwanese horror movie? Or any...         0
# 19745  How do I describe the horrors?!!! First, some ...         0
# 29191  The thing which makes "Fire" even more appeali...         1
# 48684  "Erendira" is a film from Mexico that is rarel...         1

# %% [markdown]
# ### ***Using REGEX To Clean the data***

# %%
import re
clean = re.compile('<.*?>')
re.sub(clean, '', df.iloc[2].review)
# Out:
# "How do I describe the horrors?!!! First, some points: First, this review should be taken with a grain of salt -- I saw this over 20 years ago, when I was a boy, at the Museum of Modern Art in New York City.Secondly, I am giving away some scenes and plot points. However, it does not have much of a plot.Finally, I don't enjoy these type of art films anyway.This film was directed by proto-auteur Luis Bunuel. He was a surrealist and dadaist. These were modernist themes or movements popular critically in the 1920's and early 1930's. Surealism was the school of art that made things hyper-real, yet often had Freudian symbolism. Dadaism is based on what is supposedly the first word made by an infant -- Dada, or father.Made in black and white, it was also made by a band of communists (or as they preferred the term, socialists). Bunuel and his group of fellow film-makers and artistes had been working on a number of symbolic ideas and issues in Spain and France between the world wars.Dadaism a
# ...

# %%
# Function to clean html tags
def clean_html(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
df['review']=df['review'].apply(clean_html)

# %%
# converting everything to lower

def convert_lower(text):
    return text.lower()

# %%
df['review']=df['review'].apply(convert_lower)

# %%
# function to remove special characters

def remove_special(text):
    x=''
    
    for i in text:
        if i.isalnum():
            x=x+i
        else:
            x=x + ' '
    return x

# %%
remove_special(' th%e @ classic use of the word.it is called oz as that is the nickname given to the oswald maximum security state penitentary. it focuses mainly on emerald city, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. em city is home to many..aryans, muslims, gangstas, latinos, christians, italians, irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.i would say the main appeal of the show is due to the fact that it goes where other shows wouldnt dare. forget pretty pictures painted for mainstream audiences, f')
# Out:
# ' th e   classic use of the word it is called oz as that is the nickname given to the oswald maximum security state penitentary  it focuses mainly on emerald city  an experimental section of the prison where all the cells have glass fronts and face inwards  so privacy is not high on the agenda  em city is home to many  aryans  muslims  gangstas  latinos  christians  italians  irish and more    so scuffles  death stares  dodgy dealings and shady agreements are never far away i would say the main appeal of the show is due to the fact that it goes where other shows wouldnt dare  forget pretty pictures painted for mainstream audiences  f'

# %%
df['review']=df['review'].apply(remove_special)

# %%
# Remove the stop words
import nltk

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Pradhuman\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
# ...

# %%
df
# Out:
#                                                   review sentiment
# 1750   i must say that i am fairly disappointed by th...         0
# 38342  ever heard of a taiwanese horror movie  or any...         0
# 19745  how do i describe the horrors     first  some ...         0
# 29191  the thing which makes  fire  even more appeali...         1
# 48684   erendira  is a film from mexico that is rarel...         1
# ...                                                  ...       ...
# 10292  i hate plane crash movies   all of them  in fa...         0
# 13320  i m not american  but meatballs still really h...         1
# 8670   i rate this 10 out of 10  why   it offers insi...         1
# 29925  ok i caught this film halfway through  but oh ...         0
# 41463  i loved this movie  it was almost the same as ...         1
#
# [10000 rows x 2 columns]

# %%
def remove_stopwords(text):
    x=[]
    for i in text.split():
        
        if i not in stopwords.words('english'):
            x.append(i)
    y=x[:]
    x.clear()
    return y

# %%
df['review']=df['review'].apply(remove_stopwords)

# %%
df
# Out:
#                                                   review sentiment
# 1750   [must, say, fairly, disappointed, horror, movi...         0
# 38342  [ever, heard, taiwanese, horror, movie, taiwan...         0
# 19745  [describe, horrors, first, points, first, revi...         0
# 29191  [thing, makes, fire, even, appealing, watch, a...         1
# 48684  [erendira, film, mexico, rarely, talked, film,...         1
# ...                                                  ...       ...
# 10292  [hate, plane, crash, movies, fact, hate, passi...         0
# 13320  [american, meatballs, still, really, hits, may...         1
# 8670   [rate, 10, 10, offers, insight, something, bar...         1
# 29925  [ok, caught, film, halfway, oh, dear, god, sou...         0
# 41463  [loved, movie, almost, first, cabin, lake, ins...         1
#
# [10000 rows x 2 columns]

# %%
# Perform stemming

from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
y=[]
def stem_words(text):
    for i in text:
        y.append(ps.stem(i))
    z=y[:]
    y.clear()
    return z

# %%
stem_words(['I','loved','loving','it'])
# Out:
# ['i', 'love', 'love', 'it']

# %%
df['review']=df['review'].apply(stem_words)

# %%
df
# Out:
#                                                   review sentiment
# 1750   [must, say, fairli, disappoint, horror, movi, ...         0
# 38342  [ever, heard, taiwanes, horror, movi, taiwanes...         0
# 19745  [describ, horror, first, point, first, review,...         0
# 29191  [thing, make, fire, even, appeal, watch, apart...         1
# 48684  [erendira, film, mexico, rare, talk, film, exi...         1
# ...                                                  ...       ...
# 10292  [hate, plane, crash, movi, fact, hate, passion...         0
# 13320  [american, meatbal, still, realli, hit, mayb, ...         1
# 8670   [rate, 10, 10, offer, insight, someth, bare, u...         1
# 29925  [ok, caught, film, halfway, oh, dear, god, sou...         0
# 41463  [love, movi, almost, first, cabin, lake, inste...         1
#
# [10000 rows x 2 columns]

# %%
# Join back

def join_back(list_input):
    return " ".join(list_input)

# %%
df['review']=df['review'].apply(join_back)

# %%
df['review']
# Out:
# 1750     must say fairli disappoint horror movi get sca...
# 38342    ever heard taiwanes horror movi taiwanes movi ...
# 19745    describ horror first point first review taken ...
# 29191    thing make fire even appeal watch apart magic ...
# 48684    erendira film mexico rare talk film exist low ...
#                                ...
# 10292    hate plane crash movi fact hate passion first ...
# 13320    american meatbal still realli hit mayb sweet s...
# 8670     rate 10 10 offer insight someth bare understan...
# 29925    ok caught film halfway oh dear god sound like ...
# 41463    love movi almost first cabin lake instead kill...
# Name: review, Length: 10000, dtype: str

# %%
X=df.iloc[:,0:1].values

# %%
X.shape
# Out:
# (10000, 1)

# %%
from sklearn.feature_extraction.text import CountVectorizer  # This class is used to find the Top words in data 
 # and make features based on the top words as Columns and if row contains that Word we get binary 1 otherwise 0. Done this for 2500 Features
cv=CountVectorizer(max_features=2500)

# %%
X=cv.fit_transform(df['review']).toarray()

# %%
X.shape
# Out:
# (10000, 2500)

# %%
X[0].mean()
# Out:
# np.float64(0.0148)

# %%
y=df.iloc[:,-1].values

# %%
y = y.astype(np.int32)

# %%
y.shape
# Out:
# (10000,)

# %%
# X,y
# Training set
# Test Set(Already know the result)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (8000, 2500)

# %%
X_test.shape
# Out:
# (2000, 2500)

# %%
y_train.shape
# Out:
# (8000,)

# %%
y_test.shape
# Out:
# (2000,)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
clf1=GaussianNB()
clf2=MultinomialNB()
clf3=BernoulliNB()

# %%
clf1.fit(X_train,y_train)
clf2.fit(X_train,y_train)
clf3.fit(X_train,y_train)
# Out:
# BernoulliNB()

# %%
y_pred1=clf1.predict(X_test)
y_pred2=clf2.predict(X_test)
y_pred3=clf3.predict(X_test)

# %%
y_test.shape
# Out:
# (2000,)

# %%
y_pred1.shape
# Out:
# (2000,)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Gaussian",accuracy_score(y_test,y_pred1))
print("Multinomial",accuracy_score(y_test,y_pred2))
print("Bernaulli",accuracy_score(y_test,y_pred3))
# Out:
# Gaussian 0.719
# Multinomial 0.854
# Bernaulli 0.8535

# %% [markdown]
# ### We see that Gaussian Naive Bayes Model performed the worst among the others
# - Thus the assumptions that the Features are Normally distributed is Wrong.
