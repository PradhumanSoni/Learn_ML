# %%
# Importing various libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error , root_mean_squared_error

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(f'Shape of Input Data\n{X.shape}')
print(f'Shape of Output Data\n{y.shape}')
# Out:
# Shape of Input Data
# (442, 10)
# Shape of Output Data
# (442,)

# %%
# Let us create train and testing data
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state = 13)

# %%
print(f'Shape of X_train Data\n{X_train.shape}')
print(f'Shape of y_train Data\n{y_train.shape}')
print(f'Shape of X_test Data\n{X_test.shape}')
print(f'Shape of y_test Data\n{y_test.shape}')
# Out:
# Shape of X_train Data
# (353, 10)
# Shape of y_train Data
# (353,)
# Shape of X_test Data
# (89, 10)
# Shape of y_test Data
# (89,)

# %%
# Let us fit the data and check the values of coeffs and intercepts
lr = LinearRegression()

lr.fit(X_train,y_train)

y_pred_lr = lr.predict(X_test)

print(f"Values of intercept b -> \n{lr.intercept_}")
print(f"Values of coefficients -> \n{lr.coef_}")
# Out:
# Values of intercept b ->
# 150.23367667649734
# Values of coefficients ->
# [ -17.28691266 -248.0885923   578.27946674  315.72999856 -571.32572115
#   292.43070367  -17.46493017  120.18338433  695.01416778  108.05301725]

# %%
# Let us find r2 score
r2 = r2_score(y_test,y_pred_lr)
print(f"R2 Score ->\n{r2}")
# Out:
# R2 Score ->
# 0.3670103737004128

# %%
print(f"MAE -> {mean_absolute_error(y_test,y_pred_lr)}")
print(f"RMSE -> {root_mean_squared_error(y_test,y_pred_lr)}")
# Out:
# MAE -> 45.384065811572555
# RMSE -> 55.71540522899784

# %%
# Now we will make our own class SGDRegressor
class SGDRegressor:
    def __init__(self,learning_rate,epochs):
        self.intercept_ = None
        self.coef_ = None
        self.learning_rate = learning_rate
        self.epochs = epochs
    
    def fit(self,X_train,y_train):
        #initialization
        self.intercept_ = 0
        self.coef_ = np.zeros(X_train.shape[1])
        for i in range(self.epochs):
            for j in range(X_train.shape[0]):
                # Chossing a random index 
                idx = np.random.randint(0,X_train.shape[0])

                # finding and updating each value of intercept using random row 
                y_hat = self.intercept_ + np.dot(X_train[idx],self.coef_)
                intercept_der = -2 *(y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.learning_rate * intercept_der)

                # Finding and updating coeffs using a random single row from data

                coef_der = -2 * ((y_train[idx] - y_hat) * X_train[idx])
                self.coef_ = self.coef_ - self.learning_rate * coef_der
        print(self.intercept_)
        print(self.coef_)

    def predict(self,X_test):
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
sgd = SGDRegressor(learning_rate=0.01 , epochs=50)

# %%
sgd.fit(X_train,y_train)
# Out:
# 151.46190079960013
# [  34.11478426  -82.90318551  383.16200264  250.04348455   17.53133774
#   -22.93814736 -178.96428364  141.26080826  295.3132691   172.06158797]

# %%
sgd.coef_
# Out:
# array([  34.11478426,  -82.90318551,  383.16200264,  250.04348455,
#          17.53133774,  -22.93814736, -178.96428364,  141.26080826,
#         295.3132691 ,  172.06158797])

# %%
sgd.intercept_
# Out:
# np.float64(151.46190079960013)

# %%
y_pred_sgd = sgd.predict(X_test)

# %%
r2_score(y_test,y_pred_sgd)
# Out:
# 0.38438307563302887

# %%
print(f"MAE -> {mean_absolute_error(y_test,y_pred_sgd)}")
print(f"RMSE -> {root_mean_squared_error(y_test,y_pred_sgd)}")
# Out:
# MAE -> 44.29853988519871
# RMSE -> 54.945518074617695

# %% [markdown]
# #### Using Scikit-Learn SGDRegressor Model

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor(loss = "squared_error" ,max_iter = 100, learning_rate = "constant" , eta0 = 0.01)

# %% [markdown]
# `we can change the values of loss here since SGDRegressor can be used for other loss functions also`
#
# `and learning_rate here is constant but we can set it to some different value`

# %%
sgd.fit(X_train,y_train)
# Out:
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
print(f"Intercept -> \n{sgd.intercept_}")
print(f"Coefficients -> \n{sgd.coef_}")
# Out:
# Intercept ->
# [152.49672982]
# Coefficients ->
# [  37.87916493  -67.774391    349.05152339  226.55840321   29.80961584
#    -5.11888621 -168.0047928   143.91802129  272.76967801  161.01455949]

# %%
y_pred_sgd_model = sgd.predict(X_test)

# %%
# Finding the MAE AND RMSE 
print(f"MAE -> \n{mean_absolute_error(y_test,y_pred_sgd_model)}")
print(f"RMSE -> \n{root_mean_squared_error(y_test,y_pred_sgd_model)}")
# Out:
# MAE ->
# 44.54268882854117
# RMSE ->
# 54.871286021127666

# %%
print(f"R2 Score ->\n{r2_score(y_test,y_pred_sgd_model)}")
# Out:
# R2 Score ->
# 0.386045363675545
